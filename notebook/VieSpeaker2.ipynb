# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/study_at_hust/lab_hustek # Update this path to use your own Drive folder

# %%
            ``   ``
for key in ['HUGGINGFACE_ACCESS_TOKEN', 'PYANNOTE_API_KEY']:
    os.environ[key] = userdata.get(key)

# %%
# !git clone https://github.com/hoangducanh1865/VieSpeaker2

# %%
# %cd VieSpeaker2

# %%
# !git pull

# %%
# !pip install -r requirements.txt
# !pip install --upgrade pyannote.audio
# !pip install python_speech_features
# !pip uninstall -y onnxruntime onnxruntime-gpu
# !pip install onnxruntime-gpu

# %%
# !python main.py --pipeline all
